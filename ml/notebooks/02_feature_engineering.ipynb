# %% [markdown]
# # 02. Feature Engineering & Target Leakage Prevention
# This notebook demonstrates feature engineering on quiz attempts without temporal or target leakage.

# %%
import os
import sys
sys.path.append('..')
from src.features import generate_features

df_feat = generate_features('../data/raw/quiz_attempts.csv', '../data/processed/featured_quiz_attempts.csv')
print(f"Supervised Feature Matrix Shape: {df_feat.shape}")
df_feat.head()
# Out:
# Generated expanded feature matrix with 585 rows to: ../data/processed/featured_quiz_attempts.csv
# Supervised Feature Matrix Shape: (585, 59)
#    attempt_id  user_id                 created_at  is_synthetic  target_score  \
# 0         671        3 2026-08-10 18:44:56.049108             1             6
# 1         674        3 2026-08-10 19:08:15.136172             1             3
# 2         680        3 2026-08-10 19:10:59.471939             1             3
# 3         682        3 2026-08-10 19:17:15.917704             1             6
# 4           6        4 2026-07-04 16:00:00.000000             1             6
#
#    next_percentage  next_pass  previous_score  previous_percentage  \
# 0             60.0          0             1.0                 10.0
# 1             30.0          0             6.0                 60.0
# 2             30.0          0             3.0                 30.0
# 3             60.0          0             3.0                 30.0
# 4             60.0          0             6.0                 55.0
#
#    previous_2_attempt_avg  ...  previous_average_medium_score  \
# 0                    10.0  ...                      10.000000
# 1                    35.0  ...                      35.000000
# 2                    45.0  ...                      33.333333
# 3                    30.0  ...                      32.500000
# 4                    55.0  ...                      55.000000
#
#    previous_average_hard_score  difficulty_transition_delta  difficulty_easy  \
# 0                    10.000000                          0.0                0
# 1                    35.000000                          0.0                0
# 2                    33.333333                          0.0                0
# 3                    32.500000                          0.0                0
# 4                    55.000000                          1.0                0
#
#    difficulty_medium  difficulty_hard  unique_videos_seen  \
# 0                  1                0                   1
# 1                  1                0                   1
# 2                  1                0                   1
# 3                  1                0                   1
# 4                  1                0                   1
#
#    total_previous_video_interactions  repeated_video_ratio  \
# 0                                  1              0.000000
# 1                                  2              0.500000
# 2                                  3              0.666667
# 3                                  4              0.750000
# 4                                  1              0.000000
#
#    number_of_videos_in_recent_attempts
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1
#
# [5 rows x 59 columns]

# %%
df_feat[['previous_percentage', 'previous_2_attempt_avg', 'overall_previous_avg', 'recent_score_trend', 'next_percentage']].describe()
# Out:
#        previous_percentage  previous_2_attempt_avg  overall_previous_avg  \
# count           585.000000              585.000000            585.000000
# mean             67.068376               66.141026             64.165852
# std              16.228108               16.070911             16.376583
# min              10.000000               10.000000             10.000000
# 25%              60.000000               55.000000             51.250000
# 50%              70.000000               67.500000             65.000000
# 75%              80.000000               80.000000             77.500000
# max             100.000000               95.000000             91.428571
#
#        recent_score_trend  next_percentage
# count          585.000000       585.000000
# mean             1.854701        69.358974
# std              8.405666        15.127009
# min            -50.000000        30.000000
# 25%              0.000000        60.000000
# 50%              0.000000        70.000000
# 75%             10.000000        80.000000
# max             50.000000       100.000000
